# %%
import pandas as pd
import  numpy as np

dowj_data = pd.read_csv('data/dowdata.csv')

# %%
# Out:
#                                                                                  <DATE>;<TIME>;<OPEN> ;<HIGH>;<LOW> ;<CLOSE> ;<VOL>
# 25.09.2017;100000;22 321.2236507;22 354.3047676;22 315.3034508;22 337.4241977;1                                              799.0
# 25.09.2017;110000;22 339.3342622;22 360.6349814;22 282.9723592;22 283.0623622;3                                              595.0
# 25.09.2017;120000;22 282.5423446;22 285.5024446;22 219.8602283;22 269.6519094;3                                              592.0
# 25.09.2017;130000;22 269.7619131;22 280.9922923;22 238.9508728;22 274.3620684;3                                              598.0
# 25.09.2017;140000;22 274.5220738;22 297.6928562;22 273.3520343;22 282.2023332;3                                                6.0
# 25.09.2017;150000;22 282.2723355;22 293.6827208;22 271.4019685;22 282.5223440;3                                              599.0
# ...
